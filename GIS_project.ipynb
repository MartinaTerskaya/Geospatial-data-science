# %% [markdown]
# # GIS Project "ITRF2020"

# %% [markdown]
# The tasks that are performed within this notebook:
#
# 1. Open the 4 files and keep only the stations that belongs to a site (look at the five first numbers of the DOMES (id) number) which hosts at least 3 instruments from 2 different measurement techniques (GNSS, DORIS, SLR or VLBI).
#
# 2. Calculate for each station the polygon of its extent (convex envelope) and export it as a SHP file (convert geometry from EPSG:4978 to EPSG:4326 at the begining).
#
# 3. List for each station the images (between 2022/01/01 and 2022/09/30) that are covering the extent and export it as a SHP file:
#  - For each station, write a <station_id>.json temporary file when you do the API request;
#  - Merge all information in one SHP file after.

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import scipy as sc
import geopandas as gpd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import json
import shapely
from scipy.spatial import ConvexHull
from shapely.geometry import Polygon

# %%
#Load all data and concatenate files
ITRF2020_DORIS_cart = pd.read_fwf('ipynb_checkpoints\\ITRF2020_DORIS_cart.txt')
ITRF2020_GNSS_cart = pd.read_fwf('ipynb_checkpoints\\ITRF2020_GNSS_cart.txt')
ITRF2020_SLR_cart = pd.read_fwf('ipynb_checkpoints\\ITRF2020_SLR_cart.txt')
ITRF2020_VLBI_cart = pd.read_fwf('ipynb_checkpoints\\ITRF2020_VLBI_cart.txt')
concatenated_files = pd.concat([ITRF2020_DORIS_cart, ITRF2020_GNSS_cart, ITRF2020_SLR_cart, ITRF2020_VLBI_cart])
concatenated_files
# Out:
#             id             name   type  code             x             y  \
# 0    10002S018     Grasse (OCA)  DORIS  GR3B  4.581680e+06  5.561665e+05
# 1    10002S019     Grasse (OCA)  DORIS  GR4B  4.581681e+06  5.561669e+05
# 2    10003S001         Toulouse  DORIS  TLSA  4.628047e+06  1.196707e+05
# 3    10003S003         Toulouse  DORIS  TLHA  4.628693e+06  1.199851e+05
# 4    10003S005         Toulouse  DORIS  TLSB  4.628694e+06  1.199851e+05
# ..         ...              ...    ...   ...           ...           ...
# 149  50243S001        Warkworth   VLBI  7377 -5.115324e+06  4.778433e+05
# 150  50505S003  KWAJALEIN ATOLL   VLBI  4968 -6.143536e+06  1.363999e+06
# 151  59968S001  Katherine - Nor   VLBI  7375 -4.147355e+06  4.581542e+06
# 152  66006S004            Syowa   VLBI  7342  1.766194e+06  1.460411e+06
# 153  66008S001        O'higgins   VLBI  7245  1.525833e+06 -2.432464e+06
#
#                 z      dx      dy      dz
# 0    4.389372e+06   0.002  0.0025   0.002
# 1    4.389371e+06  0.0019  0.0024  0.0017
# 2    4.372788e+06  0.0054  0.0062  0.0051
# 3    4.372105e+06  0.0034  0.0042  0.0032
# 4    4.372105e+06  0.0026  0.0039  0.0025
# ..            ...     ...     ...     ...
# 149 -3.767193e+06  0.0017  0.0012  0.0016
# 150  1.034708e+06  0.8689  0.2507  0.3272
# 151 -1.573303e+06  0.0014  0.0014  0.0012
# 152 -5.932273e+06  0.0034  0.0031  0.0071
# 153 -5.676174e+06  0.0021  0.0021  0.0026
#
# [1842 rows x 10 columns]

# %%
#Leave only 5 first symbols in id column in order to get station_id
concatenated_files['station_id'] = concatenated_files['id'].str[:5]

# %%
concatenated_files.sort_values('station_id')
# Out:
#              id             name   type  code             x             y  \
# 1     10001S007            Paris   GNSS  OP71  4.202780e+06  1.713707e+05
# 0     10001S006            Paris   GNSS  OPMT  4.202777e+06  1.713682e+05
# 0     10002S018     Grasse (OCA)  DORIS  GR3B  4.581680e+06  5.561665e+05
# 0     10002M003     Grasse (OCA)   VLBI  7605  4.581697e+06  5.561261e+05
# 1     10002S002     Grasse (OCA)    SLR  7845  4.581692e+06  5.561964e+05
# ...         ...              ...    ...   ...           ...           ...
# 1340  97401M003       La Reunion   GNSS  REUN  3.364099e+06  4.907945e+06
# 197   97401S003       La Reunion  DORIS  REUC  3.364080e+06  4.907924e+06
# 1341  97413M001          Le Port   GNSS  LEPO  3.393377e+06  4.897825e+06
# 1342  97415M001  Saint-Denis, Le   GNSS  STDE  3.376868e+06  4.912498e+06
# 1343  97501M005     Saint-Pierre   GNSS  STPM  2.436208e+06 -3.634805e+06
#
#                  z      dx      dy      dz station_id
# 1     4.778661e+06   0.001  0.0007  0.0011      10001
# 0     4.778660e+06  0.0009  0.0007  0.0009      10001
# 0     4.389372e+06   0.002  0.0025   0.002      10002
# 0     4.389352e+06   0.003  0.0027  0.0019      10002
# 1     4.389355e+06  0.0007  0.0007  0.0007      10002
# ...            ...     ...     ...     ...        ...
# 1340 -2.293467e+06  0.0031   0.004  0.0025      97401
# 197  -2.293546e+06  0.0137  0.0097  0.0086      97401
# 1341 -2.267723e+06  0.0096   0.013  0.0067      97413
# 1342 -2.260738e+06  0.0111  0.0156  0.0081      97415
# 1343  4.624886e+06  0.0012  0.0015  0.0017      97501
#
# [1842 rows x 11 columns]

# %%
#Leave only station_ids, that occure more than 2 times
station_counts = concatenated_files['station_id'].value_counts()
valid_station_id = station_counts[station_counts > 2].index
filtered_stations = concatenated_files[concatenated_files['station_id'].isin(valid_station_id)]
filtered_stations = filtered_stations.sort_values('station_id')
filtered_stations
# Out:
#              id          name   type  code             x             y  \
# 0     10002S018  Grasse (OCA)  DORIS  GR3B  4.581680e+06  5.561665e+05
# 3     10002M010  Grasse (OCA)   GNSS  GRAC  4.581708e+06  5.561328e+05
# 2     10002M006  Grasse (OCA)   GNSS  GRAS  4.581691e+06  5.561150e+05
# 1     10002S002  Grasse (OCA)    SLR  7845  4.581692e+06  5.561964e+05
# 0     10002M003  Grasse (OCA)   VLBI  7605  4.581697e+06  5.561261e+05
# ...         ...           ...    ...   ...           ...           ...
# 193   97301S004        KOUROU  DORIS  KRUB  3.855261e+06 -5.049735e+06
# 195   97401S001    La Reunion  DORIS  REUA  3.364094e+06  4.907946e+06
# 196   97401S002    La Reunion  DORIS  REUB  3.364093e+06  4.907945e+06
# 197   97401S003    La Reunion  DORIS  REUC  3.364080e+06  4.907924e+06
# 1340  97401M003    La Reunion   GNSS  REUN  3.364099e+06  4.907945e+06
#
#                  z      dx      dy      dz station_id
# 0     4.389372e+06   0.002  0.0025   0.002      10002
# 3     4.389341e+06   0.001  0.0007   0.001      10002
# 2     4.389361e+06  0.0017  0.0009  0.0015      10002
# 1     4.389355e+06  0.0007  0.0007  0.0007      10002
# 0     4.389352e+06   0.003  0.0027  0.0019      10002
# ...            ...     ...     ...     ...        ...
# 193   5.630580e+05  0.0158  0.0139  0.0129      97301
# 195  -2.293482e+06  0.0069  0.0064  0.0046      97401
# 196  -2.293482e+06   0.008   0.007  0.0046      97401
# 197  -2.293546e+06  0.0137  0.0097  0.0086      97401
# 1340 -2.293467e+06  0.0031   0.004  0.0025      97401
#
# [607 rows x 11 columns]

# %%
#Get the number of techniques for each station
technic_counts = filtered_stations.groupby('station_id')['type'].nunique()

#Get id of the stations, that have more than one technic
more_one_tech = technic_counts[technic_counts > 1]
final_stations = filtered_stations[filtered_stations['station_id'].isin(more_one_tech.index)]
number_of_stations = final_stations['station_id'].value_counts()
number_of_stations
# Out:
# 40451    20
# 14201    17
# 40405    11
# 10503    11
# 92201    11
#          ..
# 21601     3
# 41508     3
# 40439     3
# 40496     3
# 40104     3
# Name: station_id, Length: 105, dtype: int64

# %%
final_stations
# Out:
#              id          name   type  code             x             y  \
# 0     10002S018  Grasse (OCA)  DORIS  GR3B  4.581680e+06  5.561665e+05
# 3     10002M010  Grasse (OCA)   GNSS  GRAC  4.581708e+06  5.561328e+05
# 2     10002M006  Grasse (OCA)   GNSS  GRAS  4.581691e+06  5.561150e+05
# 1     10002S002  Grasse (OCA)    SLR  7845  4.581692e+06  5.561964e+05
# 0     10002M003  Grasse (OCA)   VLBI  7605  4.581697e+06  5.561261e+05
# ...         ...           ...    ...   ...           ...           ...
# 193   97301S004        KOUROU  DORIS  KRUB  3.855261e+06 -5.049735e+06
# 195   97401S001    La Reunion  DORIS  REUA  3.364094e+06  4.907946e+06
# 196   97401S002    La Reunion  DORIS  REUB  3.364093e+06  4.907945e+06
# 197   97401S003    La Reunion  DORIS  REUC  3.364080e+06  4.907924e+06
# 1340  97401M003    La Reunion   GNSS  REUN  3.364099e+06  4.907945e+06
#
#                  z      dx      dy      dz station_id
# 0     4.389372e+06   0.002  0.0025   0.002      10002
# 3     4.389341e+06   0.001  0.0007   0.001      10002
# 2     4.389361e+06  0.0017  0.0009  0.0015      10002
# 1     4.389355e+06  0.0007  0.0007  0.0007      10002
# 0     4.389352e+06   0.003  0.0027  0.0019      10002
# ...            ...     ...     ...     ...        ...
# 193   5.630580e+05  0.0158  0.0139  0.0129      97301
# 195  -2.293482e+06  0.0069  0.0064  0.0046      97401
# 196  -2.293482e+06   0.008   0.007  0.0046      97401
# 197  -2.293546e+06  0.0137  0.0097  0.0086      97401
# 1340 -2.293467e+06  0.0031   0.004  0.0025      97401
#
# [538 rows x 11 columns]

# %% [markdown]
# 2. Calculate for each station the polygon of its extent (convex envelope) and export it as a SHP file (convert geometry from EPSG:4978 to EPSG:4326 at the begining).

# %%
#Make a geodata frame from the locations of the sites with the given coordinates and transform it to CRS 4326
gdf_stations = gpd.GeoDataFrame(final_stations, geometry=gpd.points_from_xy(final_stations.x, final_stations.y, final_stations.z), crs="EPSG:4978") 
gdf_stations = gdf_stations.to_crs(4326)
gdf_stations
# Out:
#              id          name   type  code             x             y  \
# 0     10002S018  Grasse (OCA)  DORIS  GR3B  4.581680e+06  5.561665e+05
# 3     10002M010  Grasse (OCA)   GNSS  GRAC  4.581708e+06  5.561328e+05
# 2     10002M006  Grasse (OCA)   GNSS  GRAS  4.581691e+06  5.561150e+05
# 1     10002S002  Grasse (OCA)    SLR  7845  4.581692e+06  5.561964e+05
# 0     10002M003  Grasse (OCA)   VLBI  7605  4.581697e+06  5.561261e+05
# ...         ...           ...    ...   ...           ...           ...
# 193   97301S004        KOUROU  DORIS  KRUB  3.855261e+06 -5.049735e+06
# 195   97401S001    La Reunion  DORIS  REUA  3.364094e+06  4.907946e+06
# 196   97401S002    La Reunion  DORIS  REUB  3.364093e+06  4.907945e+06
# 197   97401S003    La Reunion  DORIS  REUC  3.364080e+06  4.907924e+06
# 1340  97401M003    La Reunion   GNSS  REUN  3.364099e+06  4.907945e+06
#
#                  z      dx      dy      dz station_id  \
# 0     4.389372e+06   0.002  0.0025   0.002      10002
# 3     4.389341e+06   0.001  0.0007   0.001      10002
# 2     4.389361e+06  0.0017  0.0009  0.0015      10002
# 1     4.389355e+06  0.0007  0.0007  0.0007      10002
# 0     4.389352e+06   0.003  0.0027  0.0019      10002
# ...            ...     ...     ...     ...        ...
# 193   5.630580e+05  0.0158  0.0139  0.0129      97301
# 195  -2.293482e+06  0.0069  0.0064  0.0046      97401
# 196  -2.293482e+06   0.008   0.007  0.0046      97401
# 197  -2.293546e+06  0.0137  0.0097  0.0086      97401
# 1340 -2.293467e+06  0.0031   0.004  0.0025      97401
#
#                                      geometry
# 0       POINT Z (6.92123 43.75483 1323.70087)
# 3       POINT Z (6.92077 43.75449 1319.85842)
# 2       POINT Z (6.92058 43.75474 1319.30335)
# 1       POINT Z (6.92158 43.75463 1323.34323)
# 0       POINT Z (6.92070 43.75463 1318.64665)
# ...                                       ...
# 193     POINT Z (-52.63978 5.09863 109.69563)
# 195   POINT Z (55.57177 -21.20836 1561.91250)
# 196   POINT Z (55.57177 -21.20836 1561.08916)
# 197   POINT Z (55.57176 -21.20899 1561.14383)
# 1340  POINT Z (55.57172 -21.20822 1558.37142)
#
# [538 rows x 12 columns]

# %%
#Leave only columns with station id, geometry and copy them to a new data frame
station_points = gdf_stations.filter(['station_id', 'geometry']).dissolve(by='station_id')
station_polygons = station_points.copy()
print(station_polygons)
# Out:
#                                                      geometry
# station_id
# 10002       MULTIPOINT Z (6.92058 43.75474 1319.30335, 6.9...
# 10003       MULTIPOINT Z (1.48076 43.56077 207.09635, 1.48...
# 10004       MULTIPOINT Z (-4.50383 48.40787 104.42082, -4....
# 10077       MULTIPOINT Z (8.76246 41.92747 98.24128, 8.762...
# 10202       MULTIPOINT Z (-21.99518 64.15098 95.75501, -21...
# ...                                                       ...
# 92301       MULTIPOINT Z (-134.96492 -23.13026 82.21310, -...
# 92701       MULTIPOINT Z (166.41006 -22.26983 83.06194, 16...
# 92902       MULTIPOINT Z (-178.12100 -14.30778 85.73272, -...
# 97301       MULTIPOINT Z (-52.80597 5.25219 -25.77014, -52...
# 97401       MULTIPOINT Z (55.57172 -21.20822 1558.37142, 5...
#
# [105 rows x 1 columns]

# %%
#Convert multipoints to geometries with the Convex_hull function
station_polygons.geometry = station_polygons.geometry.convex_hull
station_polygons

#Make sure to leave only polygons for shape files
polygons = station_polygons[station_polygons.geometry.type == 'Polygon']
polygons

# Save the polygons into a shapefile
polygons.to_file('polygons_for_project.shp')
# Out:
#                                                      geometry
# station_id
# 10002       POLYGON Z ((6.92077 43.75449 1319.85842, 6.920...
# 10003       POLYGON Z ((1.48489 43.54962 210.79597, 1.4812...
# 10004       POLYGON Z ((-4.49659 48.38050 65.82489, -4.503...
# 10077       POLYGON Z ((8.76270 41.92739 96.80211, 8.76246...
# 10202       POLYGON Z ((-21.95549 64.13879 93.04831, -21.9...
# ...                                                       ...
# 92301       POLYGON Z ((-134.96483 -23.13035 80.64485, -13...
# 92701       POLYGON Z ((166.41020 -22.26985 83.04824, 166....
# 92902       POLYGON Z ((-178.12095 -14.30780 84.87284, -17...
# 97301       POLYGON Z ((-52.63975 5.09847 107.24563, -52.8...
# 97401       POLYGON Z ((55.57176 -21.20899 1561.14383, 55....
#
# [105 rows x 1 columns]

# %% [markdown]
# List for each station the images (between 2022/01/01 and 2022/09/30) that are covering the extent and export it as a SHP file:
#
# For each station, write a <station_id>.json temporary file when you do the API request;
# Merge all information in one SHP file after.

# %%
from datetime import datetime
import requests
from requests.auth import HTTPBasicAuth

# Configuration
USERNAME = "username"
PASSWORD = "password"
NB_ITEMS = 20 # You can't change it in fact...

def request_images(wkt_geometry, date_1, date_2):
    items = [] # Empty list to store return elements
    start_position = 0 # You will need a while loop
    url = (
        f"https://catalogue.dataspace.copernicus.eu/resto/api/collections/Sentinel2/search.json?"
        f"cloudCover=[0,10]"
        f"&startDate={date_1}T00:00:00Z&completionDate={date_2}T23:59:59Z"
        f"&geometry={wkt_geometry}"
    )
    # Request
    r = requests.get(url)#, auth=HTTPBasicAuth(USERNAME, PASSWORD))
    # If status_code is not 200, we have an issue
    if r.status_code == 200:
        data = r.json()
        i = 0
        while i < NB_ITEMS:
            if 'features' in data:
                items += data['features']
                i+=1       
        return items
# Out:
# [{'type': 'Feature',
#   'id': '72d990e4-28b1-474d-8673-578472025aef',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[2.98128485298927, 49.6518125814149],
#      [1.6142723681857, 49.644430073461],
#      [1.64154622508021, 48.6570207750582],
#      [2.51112204193742, 48.6616482187594],
#      [2.56288577299079, 48.7732422703949],
#      [2.63058257989595, 48.917953790727],
#      [2.69867440422509, 49.0626798171847],
#      [2.76734777666624, 49.2073675306132],
#      [2.8367530153596, 49.3519651381024],
#      [2.90649613934253, 49.4965862081612],
#      [2.97617664214705, 49.6411876669432],
#      [2.98128485298927, 49.6518125814149]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C_N0500/2020/01/19/S2B_MSIL1C_20200119T110259_N0500_R094_T31UDQ_20230424T053739.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200119T110259_N0500_R094_T31UDQ_20230424T053739.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': None,
#    'startDate': '2020-01-19T11:02:59.024Z',
#    'completionDate': '2020-01-19T11:02:59.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14992,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C_N0500/2020/01/19/S2B_MSIL1C_20200119T110259_N0500_R094_T31UDQ_20230424T053739.SAFE/S2B_MSIL1C_20200119T110259_N0500_R094_T31UDQ_20230424T053739-ql.jpg',
#    'updated': '2023-10-25T22:53:05.166Z',
#    'published': '2023-10-25T22:52:51.933Z',
#    'snowCover': 0,
#    'cloudCover': 0.0763465218682871,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>2.98128485298927,49.6518125814149 1.6142723681857,49.644430073461 1.64154622508021,48.6570207750582 2.51112204193742,48.6616482187594 2.56288577299079,48.7732422703949 2.63058257989595,48.917953790727 2.69867440422509,49.0626798171847 2.76734777666624,49.2073675306132 2.8367530153596,49.3519651381024 2.90649613934253,49.4965862081612 2.97617664214705,49.6411876669432 2.98128485298927,49.6518125814149</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.1943965812683, 49.1904677430072]},
#    'orbitDirection': None,
#    'timeliness': None,
#    'relativeOrbitNumber': 94,
#    'processingBaseline': 5.0,
#    'missionTakeId': 'GS2B_20200119T110259_014992_N05.00',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/72d990e4-28b1-474d-8673-578472025aef',
#      'mimeType': 'application/octet-stream',
#      'size': 632573763}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 72d990e4-28b1-474d-8673-578472025aef',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/72d990e4-28b1-474d-8673-578472025aef.json'}]}},
#  {'type': 'Feature',
#   'id': 'fc11fdc3-e6a1-45c7-b3cc-43741c6347de',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[2.98128485298927, 49.6518125814149],
#      [1.6142723681857, 49.644430073461],
#      [1.64154622508021, 48.6570207750582],
#      [2.51112204193742, 48.6616482187594],
#      [2.56288577299079, 48.7732422703949],
#      [2.63058257989595, 48.917953790727],
#      [2.69867440422509, 49.0626798171847],
#      [2.76734777666624, 49.2073675306132],
#      [2.8367530153596, 49.3519651381024],
#      [2.90649613934253, 49.4965862081612],
#      [2.97617664214705, 49.6411876669432],
#      [2.98128485298927, 49.6518125814149]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A_N0500/2020/01/19/S2B_MSIL2A_20200119T110259_N0500_R094_T31UDQ_20230424T222824.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL2A_20200119T110259_N0500_R094_T31UDQ_20230424T222824.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': None,
#    'startDate': '2020-01-19T11:02:59.024Z',
#    'completionDate': '2020-01-19T11:02:59.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 0,
#    'sensorMode': None,
#    'orbitNumber': 14992,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A_N0500/2020/01/19/S2B_MSIL2A_20200119T110259_N0500_R094_T31UDQ_20230424T222824.SAFE/S2B_MSIL2A_20200119T110259_N0500_R094_T31UDQ_20230424T222824-ql.jpg',
#    'updated': '2023-10-25T23:21:23.007Z',
#    'published': '2023-10-25T23:21:10.863Z',
#    'snowCover': 0,
#    'cloudCover': 0.804719,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>2.98128485298927,49.6518125814149 1.6142723681857,49.644430073461 1.64154622508021,48.6570207750582 2.51112204193742,48.6616482187594 2.56288577299079,48.7732422703949 2.63058257989595,48.917953790727 2.69867440422509,49.0626798171847 2.76734777666624,49.2073675306132 2.8367530153596,49.3519651381024 2.90649613934253,49.4965862081612 2.97617664214705,49.6411876669432 2.98128485298927,49.6518125814149</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.1943965812683, 49.1904677430072]},
#    'orbitDirection': None,
#    'timeliness': None,
#    'relativeOrbitNumber': 94,
#    'processingBaseline': 5.0,
#    'missionTakeId': 'GS2B_20200119T110259_014992_N05.00',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/fc11fdc3-e6a1-45c7-b3cc-43741c6347de',
#      'mimeType': 'application/octet-stream',
#      'size': 953895694}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for fc11fdc3-e6a1-45c7-b3cc-43741c6347de',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/fc11fdc3-e6a1-45c7-b3cc-43741c6347de.json'}]}},
#  {'type': 'Feature',
#   'id': 'd04127cb-788d-56b9-8cb3-a69a917a4f29',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[2.9813086012307, 49.651812709666],
#      [2.9761994914574, 49.641182168598],
#      [2.9064988969064, 49.496585543872],
#      [2.8367473533309, 49.351966503787],
#      [2.7673529603611, 49.207366278873],
#      [2.6986764317353, 49.062679327059],
#      [2.6305739316499, 48.917955883382],
#      [2.5628789123799, 48.773243931894],
#      [2.5111175544551, 48.661648194879],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461],
#      [2.9813086012307, 49.651812709666]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A/2020/01/19/S2B_MSIL2A_20200119T110259_N0213_R094_T31UDQ_20200119T121843.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL2A_20200119T110259_N0213_R094_T31UDQ_20200119T121843.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-19T11:02:59.024Z',
#    'completionDate': '2020-01-19T11:02:59.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': '',
#    'orbitNumber': 14992,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A/2020/01/19/S2B_MSIL2A_20200119T110259_N0213_R094_T31UDQ_20200119T121843.SAFE/S2B_MSIL2A_20200119T110259_N0213_R094_T31UDQ_20200119T121843-ql.jpg',
#    'updated': '2020-01-19T20:19:46.343Z',
#    'published': '2020-01-19T20:19:46.343Z',
#    'snowCover': 0,
#    'cloudCover': 0.832098,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>2.9813086012307,49.651812709666 2.9761994914574,49.641182168598 2.9064988969064,49.496585543872 2.8367473533309,49.351966503787 2.7673529603611,49.207366278873 2.6986764317353,49.062679327059 2.6305739316499,48.917955883382 2.5628789123799,48.773243931894 2.5111175544551,48.661648194879 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461 2.9813086012307,49.651812709666</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.1943974159613227, 49.190469304908035]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 94,
#    'processingBaseline': 2.13,
#    'missionTakeId': 'GS2B_20200119T110259_014992_N02.13',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/d04127cb-788d-56b9-8cb3-a69a917a4f29',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for d04127cb-788d-56b9-8cb3-a69a917a4f29',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/d04127cb-788d-56b9-8cb3-a69a917a4f29.json'}]}},
#  {'type': 'Feature',
#   'id': 'aaa3f62b-88f2-541a-ab7c-fcba0354f3d7',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[2.9813086012307, 49.651812709666],
#      [2.9761994914574, 49.641182168598],
#      [2.9064988969064, 49.496585543872],
#      [2.8367473533309, 49.351966503787],
#      [2.7673529603611, 49.207366278873],
#      [2.6986764317353, 49.062679327059],
#      [2.6305739316499, 48.917955883382],
#      [2.5628789123799, 48.773243931894],
#      [2.5111175544551, 48.661648194879],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461],
#      [2.9813086012307, 49.651812709666]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C/2020/01/19/S2B_MSIL1C_20200119T110259_N0208_R094_T31UDQ_20200119T113522.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200119T110259_N0208_R094_T31UDQ_20200119T113522.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-19T11:02:59.024Z',
#    'completionDate': '2020-01-19T11:02:59.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14992,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C/2020/01/19/S2B_MSIL1C_20200119T110259_N0208_R094_T31UDQ_20200119T113522.SAFE/S2B_MSIL1C_20200119T110259_N0208_R094_T31UDQ_20200119T113522-ql.jpg',
#    'updated': '2020-01-19T13:44:14.341Z',
#    'published': '2020-01-19T13:44:14.341Z',
#    'snowCover': 0,
#    'cloudCover': 0.1653,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>2.9813086012307,49.651812709666 2.9761994914574,49.641182168598 2.9064988969064,49.496585543872 2.8367473533309,49.351966503787 2.7673529603611,49.207366278873 2.6986764317353,49.062679327059 2.6305739316499,48.917955883382 2.5628789123799,48.773243931894 2.5111175544551,48.661648194879 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461 2.9813086012307,49.651812709666</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.1943974159613227, 49.190469304908035]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 94,
#    'processingBaseline': 2.08,
#    'missionTakeId': 'GS2B_20200119T110259_014992_N02.08',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/aaa3f62b-88f2-541a-ab7c-fcba0354f3d7',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for aaa3f62b-88f2-541a-ab7c-fcba0354f3d7',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/aaa3f62b-88f2-541a-ab7c-fcba0354f3d7.json'}]}},
#  {'type': 'Feature',
#   'id': 'da2d5d44-a7a9-46c8-a3a3-ec57bec31d14',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [1.64154622508021, 48.6570207750582],
#      [3.13255132712365, 48.6649551518361],
#      [3.13521359578094, 49.6526438687518],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C_N0500/2020/01/06/S2B_MSIL1C_20200106T105339_N0500_R051_T31UDQ_20230421T103014.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200106T105339_N0500_R051_T31UDQ_20230421T103014.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': None,
#    'startDate': '2020-01-06T10:53:39.024Z',
#    'completionDate': '2020-01-06T10:53:39.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14806,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C_N0500/2020/01/06/S2B_MSIL1C_20200106T105339_N0500_R051_T31UDQ_20230421T103014.SAFE/S2B_MSIL1C_20200106T105339_N0500_R051_T31UDQ_20230421T103014-ql.jpg',
#    'updated': '2023-10-21T19:33:45.182Z',
#    'published': '2023-10-21T19:33:35.984Z',
#    'snowCover': 0,
#    'cloudCover': 1.22129654513422,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 1.64154622508021,48.6570207750582 3.13255132712365,48.6649551518361 3.13521359578094,49.6526438687518 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.38089060453406, 49.1563985255633]},
#    'orbitDirection': None,
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 5.0,
#    'missionTakeId': 'GS2B_20200106T105339_014806_N05.00',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/da2d5d44-a7a9-46c8-a3a3-ec57bec31d14',
#      'mimeType': 'application/octet-stream',
#      'size': 838034521}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for da2d5d44-a7a9-46c8-a3a3-ec57bec31d14',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/da2d5d44-a7a9-46c8-a3a3-ec57bec31d14.json'}]}},
#  {'type': 'Feature',
#   'id': '11016661-93a3-410e-a93a-14cbbc047d9b',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [1.64154622508021, 48.6570207750582],
#      [3.13255132712365, 48.6649551518361],
#      [3.13521359578094, 49.6526438687518],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A_N0500/2020/01/21/S2A_MSIL2A_20200121T105341_N0500_R051_T31UDQ_20230427T135726.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2A_MSIL2A_20200121T105341_N0500_R051_T31UDQ_20230427T135726.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': None,
#    'startDate': '2020-01-21T10:53:41.024Z',
#    'completionDate': '2020-01-21T10:53:41.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2A',
#    'instrument': 'MSI',
#    'resolution': 0,
#    'sensorMode': None,
#    'orbitNumber': 23929,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A_N0500/2020/01/21/S2A_MSIL2A_20200121T105341_N0500_R051_T31UDQ_20230427T135726.SAFE/S2A_MSIL2A_20200121T105341_N0500_R051_T31UDQ_20230427T135726-ql.jpg',
#    'updated': '2023-10-23T12:49:50.356Z',
#    'published': '2023-10-23T12:49:33.579Z',
#    'snowCover': 0,
#    'cloudCover': 1.7262960000000003,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 1.64154622508021,48.6570207750582 3.13255132712365,48.6649551518361 3.13521359578094,49.6526438687518 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.38089060453406, 49.1563985255633]},
#    'orbitDirection': None,
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 5.0,
#    'missionTakeId': 'GS2A_20200121T105341_023929_N05.00',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/11016661-93a3-410e-a93a-14cbbc047d9b',
#      'mimeType': 'application/octet-stream',
#      'size': 1210988081}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 11016661-93a3-410e-a93a-14cbbc047d9b',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/11016661-93a3-410e-a93a-14cbbc047d9b.json'}]}},
#  {'type': 'Feature',
#   'id': 'd8b32b71-8eef-40fc-b36c-35274d66e34d',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [1.64154622508021, 48.6570207750582],
#      [3.13255132712365, 48.6649551518361],
#      [3.13521359578094, 49.6526438687518],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C_N0500/2020/01/21/S2A_MSIL1C_20200121T105341_N0500_R051_T31UDQ_20230426T174147.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2A_MSIL1C_20200121T105341_N0500_R051_T31UDQ_20230426T174147.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': None,
#    'startDate': '2020-01-21T10:53:41.024Z',
#    'completionDate': '2020-01-21T10:53:41.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2A',
#    'instrument': 'MSI',
#    'resolution': 0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 23929,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C_N0500/2020/01/21/S2A_MSIL1C_20200121T105341_N0500_R051_T31UDQ_20230426T174147.SAFE/S2A_MSIL1C_20200121T105341_N0500_R051_T31UDQ_20230426T174147-ql.jpg',
#    'updated': '2023-10-23T12:58:57.918Z',
#    'published': '2023-10-23T12:58:47.354Z',
#    'snowCover': 0,
#    'cloudCover': 0.0643494878915465,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 1.64154622508021,48.6570207750582 3.13255132712365,48.6649551518361 3.13521359578094,49.6526438687518 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.38089060453406, 49.1563985255633]},
#    'orbitDirection': None,
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 5.0,
#    'missionTakeId': 'GS2A_20200121T105341_023929_N05.00',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/d8b32b71-8eef-40fc-b36c-35274d66e34d',
#      'mimeType': 'application/octet-stream',
#      'size': 840393268}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for d8b32b71-8eef-40fc-b36c-35274d66e34d',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/d8b32b71-8eef-40fc-b36c-35274d66e34d.json'}]}},
#  {'type': 'Feature',
#   'id': '4451c44e-6ae3-4195-b3c1-e5f7216a66ba',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [1.64154622508021, 48.6570207750582],
#      [3.13255132712365, 48.6649551518361],
#      [3.13521359578094, 49.6526438687518],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A_N0500/2020/01/06/S2B_MSIL2A_20200106T105339_N0500_R051_T31UDQ_20230422T070034.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL2A_20200106T105339_N0500_R051_T31UDQ_20230422T070034.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': None,
#    'startDate': '2020-01-06T10:53:39.024Z',
#    'completionDate': '2020-01-06T10:53:39.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 0,
#    'sensorMode': None,
#    'orbitNumber': 14806,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A_N0500/2020/01/06/S2B_MSIL2A_20200106T105339_N0500_R051_T31UDQ_20230422T070034.SAFE/S2B_MSIL2A_20200106T105339_N0500_R051_T31UDQ_20230422T070034-ql.jpg',
#    'updated': '2023-10-23T22:33:02.097Z',
#    'published': '2023-10-21T20:09:28.513Z',
#    'snowCover': 0,
#    'cloudCover': 3.322458,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 1.64154622508021,48.6570207750582 3.13255132712365,48.6649551518361 3.13521359578094,49.6526438687518 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.38089060453406, 49.1563985255633]},
#    'orbitDirection': None,
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 5.0,
#    'missionTakeId': 'GS2B_20200106T105339_014806_N05.00',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/4451c44e-6ae3-4195-b3c1-e5f7216a66ba',
#      'mimeType': 'application/octet-stream',
#      'size': 1204874523}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 4451c44e-6ae3-4195-b3c1-e5f7216a66ba',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/4451c44e-6ae3-4195-b3c1-e5f7216a66ba.json'}]}},
#  {'type': 'Feature',
#   'id': '7f793612-dfbb-4097-81cf-d583ee662aef',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [1.64154622508021, 48.6570207750582],
#      [3.13255132712365, 48.6649551518361],
#      [3.13521359578094, 49.6526438687518],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C_N0500/2020/01/16/S2B_MSIL1C_20200116T105309_N0500_R051_T31UDQ_20230428T203915.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200116T105309_N0500_R051_T31UDQ_20230428T203915.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': None,
#    'startDate': '2020-01-16T10:53:09.024Z',
#    'completionDate': '2020-01-16T10:53:09.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14949,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C_N0500/2020/01/16/S2B_MSIL1C_20200116T105309_N0500_R051_T31UDQ_20230428T203915.SAFE/S2B_MSIL1C_20200116T105309_N0500_R051_T31UDQ_20230428T203915-ql.jpg',
#    'updated': '2023-10-26T03:47:13.006Z',
#    'published': '2023-10-26T03:47:03.205Z',
#    'snowCover': 0,
#    'cloudCover': 2.10651258622234,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 1.64154622508021,48.6570207750582 3.13255132712365,48.6649551518361 3.13521359578094,49.6526438687518 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.38089060453406, 49.1563985255633]},
#    'orbitDirection': None,
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 5.0,
#    'missionTakeId': 'GS2B_20200116T105309_014949_N05.00',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/7f793612-dfbb-4097-81cf-d583ee662aef',
#      'mimeType': 'application/octet-stream',
#      'size': 834609453}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 7f793612-dfbb-4097-81cf-d583ee662aef',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/7f793612-dfbb-4097-81cf-d583ee662aef.json'}]}},
#  {'type': 'Feature',
#   'id': 'ddfcac0d-f314-5935-97a7-23bcbb345324',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A/2020/01/06/S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-06T10:53:39.024Z',
#    'completionDate': '2020-01-06T10:53:39.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': '',
#    'orbitNumber': 14806,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A/2020/01/06/S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433.SAFE/S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433-ql.jpg',
#    'updated': '2020-01-06T18:27:31.413Z',
#    'published': '2020-01-06T18:27:31.413Z',
#    'snowCover': 0,
#    'cloudCover': 1.37694,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.13,
#    'missionTakeId': 'GS2B_20200106T105339_014806_N02.13',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/ddfcac0d-f314-5935-97a7-23bcbb345324',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for ddfcac0d-f314-5935-97a7-23bcbb345324',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/ddfcac0d-f314-5935-97a7-23bcbb345324.json'}]}},
#  {'type': 'Feature',
#   'id': 'eb756c13-a23e-52d9-899f-438fdfd0f593',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C/2020/01/06/S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-06T10:53:39.024Z',
#    'completionDate': '2020-01-06T10:53:39.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14806,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C/2020/01/06/S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648.SAFE/S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648-ql.jpg',
#    'updated': '2020-01-06T14:49:28.988Z',
#    'published': '2020-01-06T14:49:28.988Z',
#    'snowCover': 0,
#    'cloudCover': 0.0989,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.08,
#    'missionTakeId': 'GS2B_20200106T105339_014806_N02.08',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/eb756c13-a23e-52d9-899f-438fdfd0f593',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for eb756c13-a23e-52d9-899f-438fdfd0f593',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/eb756c13-a23e-52d9-899f-438fdfd0f593.json'}]}},
#  {'type': 'Feature',
#   'id': 'e1a49674-5267-5e88-9f30-7eea14f8fd3d',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A/2020/01/16/S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-16T10:53:09.024Z',
#    'completionDate': '2020-01-16T10:53:09.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': '',
#    'orbitNumber': 14949,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A/2020/01/16/S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813.SAFE/S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813-ql.jpg',
#    'updated': '2020-01-16T15:12:33.763Z',
#    'published': '2020-01-16T15:12:33.763Z',
#    'snowCover': 0,
#    'cloudCover': 4.131618,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.13,
#    'missionTakeId': 'GS2B_20200116T105309_014949_N02.13',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/e1a49674-5267-5e88-9f30-7eea14f8fd3d',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for e1a49674-5267-5e88-9f30-7eea14f8fd3d',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/e1a49674-5267-5e88-9f30-7eea14f8fd3d.json'}]}},
#  {'type': 'Feature',
#   'id': '52364bcb-19f1-5cb6-a51d-5284cb128a35',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C/2020/01/16/S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-16T10:53:09.024Z',
#    'completionDate': '2020-01-16T10:53:09.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14949,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C/2020/01/16/S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704.SAFE/S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704-ql.jpg',
#    'updated': '2020-01-16T16:41:39.707Z',
#    'published': '2020-01-16T16:41:39.707Z',
#    'snowCover': 0,
#    'cloudCover': 1.6783999999999997,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.08,
#    'missionTakeId': 'GS2B_20200116T105309_014949_N02.08',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/52364bcb-19f1-5cb6-a51d-5284cb128a35',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 52364bcb-19f1-5cb6-a51d-5284cb128a35',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/52364bcb-19f1-5cb6-a51d-5284cb128a35.json'}]}},
#  {'type': 'Feature',
#   'id': '8a82d15d-7605-58f0-9488-1a6c4f18df4e',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C/2020/01/21/S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-21T10:53:41.024Z',
#    'completionDate': '2020-01-21T10:53:41.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2A',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 23929,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C/2020/01/21/S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353.SAFE/S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353-ql.jpg',
#    'updated': '2020-01-21T14:29:24.659Z',
#    'published': '2020-01-21T14:29:24.659Z',
#    'snowCover': 0,
#    'cloudCover': 4.1555,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.08,
#    'missionTakeId': 'GS2A_20200121T105341_023929_N02.08',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/8a82d15d-7605-58f0-9488-1a6c4f18df4e',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 8a82d15d-7605-58f0-9488-1a6c4f18df4e',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/8a82d15d-7605-58f0-9488-1a6c4f18df4e.json'}]}},
#  {'type': 'Feature',
#   'id': '72d990e4-28b1-474d-8673-578472025aef',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[2.98128485298927, 49.6518125814149],
#      [1.6142723681857, 49.644430073461],
# ...
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A/2020/01/06/S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-06T10:53:39.024Z',
#    'completionDate': '2020-01-06T10:53:39.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': '',
#    'orbitNumber': 14806,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A/2020/01/06/S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433.SAFE/S2B_MSIL2A_20200106T105339_N0213_R051_T31UDQ_20200106T121433-ql.jpg',
#    'updated': '2020-01-06T18:27:31.413Z',
#    'published': '2020-01-06T18:27:31.413Z',
#    'snowCover': 0,
#    'cloudCover': 1.37694,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.13,
#    'missionTakeId': 'GS2B_20200106T105339_014806_N02.13',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/ddfcac0d-f314-5935-97a7-23bcbb345324',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for ddfcac0d-f314-5935-97a7-23bcbb345324',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/ddfcac0d-f314-5935-97a7-23bcbb345324.json'}]}},
#  {'type': 'Feature',
#   'id': 'eb756c13-a23e-52d9-899f-438fdfd0f593',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C/2020/01/06/S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-06T10:53:39.024Z',
#    'completionDate': '2020-01-06T10:53:39.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14806,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C/2020/01/06/S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648.SAFE/S2B_MSIL1C_20200106T105339_N0208_R051_T31UDQ_20200106T112648-ql.jpg',
#    'updated': '2020-01-06T14:49:28.988Z',
#    'published': '2020-01-06T14:49:28.988Z',
#    'snowCover': 0,
#    'cloudCover': 0.0989,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.08,
#    'missionTakeId': 'GS2B_20200106T105339_014806_N02.08',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/eb756c13-a23e-52d9-899f-438fdfd0f593',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for eb756c13-a23e-52d9-899f-438fdfd0f593',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/eb756c13-a23e-52d9-899f-438fdfd0f593.json'}]}},
#  {'type': 'Feature',
#   'id': 'e1a49674-5267-5e88-9f30-7eea14f8fd3d',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L2A/2020/01/16/S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-16T10:53:09.024Z',
#    'completionDate': '2020-01-16T10:53:09.024Z',
#    'productType': 'S2MSI2A',
#    'processingLevel': 'S2MSI2A',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': '',
#    'orbitNumber': 14949,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L2A/2020/01/16/S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813.SAFE/S2B_MSIL2A_20200116T105309_N0213_R051_T31UDQ_20200116T122813-ql.jpg',
#    'updated': '2020-01-16T15:12:33.763Z',
#    'published': '2020-01-16T15:12:33.763Z',
#    'snowCover': 0,
#    'cloudCover': 4.131618,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.13,
#    'missionTakeId': 'GS2B_20200116T105309_014949_N02.13',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/e1a49674-5267-5e88-9f30-7eea14f8fd3d',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for e1a49674-5267-5e88-9f30-7eea14f8fd3d',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/e1a49674-5267-5e88-9f30-7eea14f8fd3d.json'}]}},
#  {'type': 'Feature',
#   'id': '52364bcb-19f1-5cb6-a51d-5284cb128a35',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C/2020/01/16/S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-16T10:53:09.024Z',
#    'completionDate': '2020-01-16T10:53:09.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2B',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 14949,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C/2020/01/16/S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704.SAFE/S2B_MSIL1C_20200116T105309_N0208_R051_T31UDQ_20200116T115704-ql.jpg',
#    'updated': '2020-01-16T16:41:39.707Z',
#    'published': '2020-01-16T16:41:39.707Z',
#    'snowCover': 0,
#    'cloudCover': 1.6783999999999997,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.08,
#    'missionTakeId': 'GS2B_20200116T105309_014949_N02.08',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/52364bcb-19f1-5cb6-a51d-5284cb128a35',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 52364bcb-19f1-5cb6-a51d-5284cb128a35',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/52364bcb-19f1-5cb6-a51d-5284cb128a35.json'}]}},
#  {'type': 'Feature',
#   'id': '8a82d15d-7605-58f0-9488-1a6c4f18df4e',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[1.6142723681857, 49.644430073461],
#      [3.1352135957809, 49.652643868752],
#      [3.1325513271237, 48.664955151836],
#      [1.6415462250802, 48.657020775058],
#      [1.6142723681857, 49.644430073461]]]},
#   'properties': {'collection': 'SENTINEL-2',
#    'status': 'ONLINE',
#    'license': {'licenseId': 'unlicensed',
#     'hasToBeSigned': 'never',
#     'grantedCountries': None,
#     'grantedOrganizationCountries': None,
#     'grantedFlags': None,
#     'viewService': 'public',
#     'signatureQuota': -1,
#     'description': {'shortName': 'No license'}},
#    'productIdentifier': '/eodata/Sentinel-2/MSI/L1C/2020/01/21/S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353.SAFE',
#    'parentIdentifier': None,
#    'title': 'S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353.SAFE',
#    'description': 'The Copernicus Sentinel-2 mission consists of two polar-orbiting satellites that are positioned in the same sun-synchronous orbit, with a phase difference of 180°. It aims to monitor changes in land surface conditions. The satellites have a wide swath width (290 km) and a high revisit time. Sentinel-2 is equipped with an optical instrument payload that samples 13 spectral bands: four bands at 10 m, six bands at 20 m and three bands at 60 m spatial resolution [https://dataspace.copernicus.eu/explore-data/data-collections/sentinel-data/sentinel-2].',
#    'organisationName': 'ESA',
#    'startDate': '2020-01-21T10:53:41.024Z',
#    'completionDate': '2020-01-21T10:53:41.024Z',
#    'productType': 'S2MSI1C',
#    'processingLevel': 'S2MSI1C',
#    'platform': 'S2A',
#    'instrument': 'MSI',
#    'resolution': 60.0,
#    'sensorMode': 'INS-NOBS',
#    'orbitNumber': 23929,
#    'quicklook': None,
#    'thumbnail': 'https://catalogue.dataspace.copernicus.eu/get-object?path=/Sentinel-2/MSI/L1C/2020/01/21/S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353.SAFE/S2A_MSIL1C_20200121T105341_N0208_R051_T31UDQ_20200121T113353-ql.jpg',
#    'updated': '2020-01-21T14:29:24.659Z',
#    'published': '2020-01-21T14:29:24.659Z',
#    'snowCover': 0,
#    'cloudCover': 4.1555,
#    'gmlgeometry': '<gml:Polygon srsName="EPSG:4326"><gml:outerBoundaryIs><gml:LinearRing><gml:coordinates>1.6142723681857,49.644430073461 3.1352135957809,49.652643868752 3.1325513271237,48.664955151836 1.6415462250802,48.657020775058 1.6142723681857,49.644430073461</gml:coordinates></gml:LinearRing></gml:outerBoundaryIs></gml:Polygon>',
#    'centroid': {'type': 'Point',
#     'coordinates': [2.3808906045340774, 49.15639852556323]},
#    'orbitDirection': 'DESCENDING',
#    'timeliness': None,
#    'relativeOrbitNumber': 51,
#    'processingBaseline': 2.08,
#    'missionTakeId': 'GS2A_20200121T105341_023929_N02.08',
#    'services': {'download': {'url': 'https://catalogue.dataspace.copernicus.eu/download/8a82d15d-7605-58f0-9488-1a6c4f18df4e',
#      'mimeType': 'application/octet-stream',
#      'size': 0}},
#    'links': [{'rel': 'self',
#      'type': 'application/json',
#      'title': 'GeoJSON link for 8a82d15d-7605-58f0-9488-1a6c4f18df4e',
#      'href': 'https://catalogue.dataspace.copernicus.eu/resto/collections/SENTINEL-2/8a82d15d-7605-58f0-9488-1a6c4f18df4e.json'}]}}]

# %%
#Make a list of temporal json files
temp_json_files = []

#Perform the request for all polygons in the df
for geom in polygons.geometry:
    temp_json_file = request_images(geom, datetime(2022, 1, 1).date(), datetime(2022, 9, 30).date())
    temp_json_files.append(temp_json_file)

# %%
#Check the number of requested images. 
len(temp_json_files)
# Out:
# 105

# %%
#Check how to get the final coordinates from the output dictionary
temp_json_files[0]
temp_json_files[0][0]['geometry']['coordinates'][0]
# Out:
# [[6.53537600651285, 43.2720289149594],
#  [6.53677232313667, 43.2382625533271],
#  [7.8886830141923, 43.2593919105371],
#  [7.87023728676149, 44.2478306839688],
#  [6.85573170854089, 44.2316889568923],
#  [6.80770452180834, 44.0916012054146],
#  [6.7580017505525, 43.9450313739555],
#  [6.70988060072912, 43.7980728382952],
#  [6.66052015967677, 43.6515224445036],
#  [6.61099005955164, 43.5050672681946],
#  [6.56336414120084, 43.3580741142308],
#  [6.53537600651285, 43.2720289149594]]

# %%
#Make a geodata frame from the requested images
output_list = []
i = 0
while i < len(temp_json_files):
    coordinates = temp_json_files[i][0]['geometry']['coordinates'][0]
    polygon_geom = Polygon(coordinates)
    output_list.append({'geometry': polygon_geom})
    i += 1
api_images = gpd.GeoDataFrame(output_list)

#Save the data frame to a shapefile
api_images.to_file("api_images.shp", driver='ESRI Shapefile')

api_images
# Out:
#                                               geometry
# 0    POLYGON ((6.53538 43.27203, 6.53677 43.23826, ...
# 1    POLYGON ((0.49593 44.22596, 0.53677 43.23826, ...
# 2    POLYGON ((-4.21863 48.39357, -4.22702 48.74648...
# 3    POLYGON ((7.78352 42.44624, 7.80218 41.45752, ...
# 4    POLYGON ((-23.11307 64.88918, -23.04007 63.924...
# ..                                                 ...
# 100  POLYGON ((-134.83974 -22.60596, -135.00020 -22...
# 101  POLYGON ((165.96675 -21.70060, 165.97356 -22.6...
# 102  POLYGON ((-178.60390 -14.55535, -177.83730 -14...
# 103  POLYGON ((-53.50034 4.43056, -52.71429 4.43291...
# 104  POLYGON ((55.92996 -21.75481, 56.07207 -21.789...
#
# [105 rows x 1 columns]
